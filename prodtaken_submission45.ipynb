# %% [markdown]
# <a href="https://colab.research.google.com/github/skyshine460/ProdTaken/blob/main/prodtaken_submission45.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
submit10 = pd.read_csv('/content/drive/MyDrive/契約予測（SIGNATE Cup 2024）/提出/prodtaken_submission10.csv', header=None)
submit13 = pd.read_csv('/content/drive/MyDrive/契約予測（SIGNATE Cup 2024）/提出/prodtaken_submission10.csv', header=None)
submit33 = pd.read_csv('/content/drive/MyDrive/契約予測（SIGNATE Cup 2024）/提出/prodtaken_submission33.csv', header=None)
submit40 = pd.read_csv('/content/drive/MyDrive/契約予測（SIGNATE Cup 2024）/提出/prodtaken_submission40.csv', header=None)

# %%
submit33.head()
# Out:
#       0         1
# 0  3489  0.081815
# 1  3490  0.238802
# 2  3491  0.257278
# 3  3492  0.316058
# 4  3493  0.299742

# %%
y_pred_prob = (1*submit10.iloc[:, 1] + 1*submit13.iloc[:, 1] + 1*submit33.iloc[:, 1]) /3.0 #45
# y_pred_prob = (1*submit10.iloc[:, 1] + 0.5*submit13.iloc[:, 1] + 0.5*submit33.iloc[:, 1]) /2.0 #44
# y_pred_prob = (1*submit10.iloc[:, 1] + 0.2*submit13.iloc[:, 1] + 0.3*submit33.iloc[:, 1] + 0.2*submit40.iloc[:, 1]) /1.7 #42
# y_pred_prob = (1*submit10.iloc[:, 1] + 0.3*submit33.iloc[:, 1] + 0.2*submit40.iloc[:, 1]) /1.5 #41
# y_pred_prob = (1*submit10.iloc[:, 1] + 0.2*submit13.iloc[:, 1] + 0.3*submit33.iloc[:, 1]) /1.6 #37
# y_pred_prob = (1*submit10.iloc[:, 1] + 0.2*submit13.iloc[:, 1] + 0.4*submit33.iloc[:, 1]) /1.6 #36
# y_pred_prob = (1*submit10.iloc[:, 1] + 0.2*submit13.iloc[:, 1] + 0.5*submit33.iloc[:, 1]) /1.7 #35
# y_pred_prob = (1*submit10.iloc[:, 1] + 0.5*submit33.iloc[:, 1]) /1.5 #34
y_pred_prob

sub = pd.read_csv('/content/drive/MyDrive/契約予測（SIGNATE Cup 2024）/提供データ/sample_submit.csv', header=None)
test_ids = sub.iloc[:, 0]

submission = pd.DataFrame({
    'id': test_ids,
    'prob': y_pred_prob
})

submission_name = "prodtaken_submission45"

submission.to_csv(f'{submission_name}.csv', index=False, header=None)
submission.head(10)
# Out:
#      id      prob
# 0  3489  0.102092
# 1  3490  0.213331
# 2  3491  0.271785
# 3  3492  0.366316
# 4  3493  0.322856
# 5  3494  0.027207
# 6  3495  0.268326
# 7  3496  0.046515
# 8  3497  0.287701
# 9  3498  0.453364
